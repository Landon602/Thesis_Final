# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1,len(deep_np_train_loss)+1), deep_np_train_loss, label='Deep NP')
plt.plot(range(1,len(deep_param_train_loss) + 1), deep_param_train_loss, label='Deep Param')
plt.plot(range(1,len(shallow_np_train_loss) +1), shallow_np_train_loss, label='Shallow NP')
plt.plot(range(1,len(shallow_param_train_loss) +1), shallow_param_train_loss, label='Shallow Param')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.title('Training Loss by Epoch')
plt.legend()
plt.savefig("/Users/Landon/Desktop/thesis/results/combined_loss.eps", format="eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1,len(deep_np_validation_loss)+1), deep_np_validation_loss, label='Deep NP')
plt.plot(range(1,len(deep_param_validation_loss) + 1), deep_param_validation_loss, label='Deep Param')
plt.plot(range(1,len(shallow_np_validation_loss) +1), shallow_np_validation_loss, label='Shallow NP')
plt.plot(range(1,len(shallow_param_validation_loss) +1), shallow_param_validation_loss, label='Shallow Param')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.title('Validation Loss by Epoch')
plt.legend()
plt.savefig("/Users/Landon/Desktop/thesis/results/validation_combined_loss.eps", format="eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
shallow_memory = [121896960,121896960,121896960,121896960,121896960,121896960,121896960,121896960,121896960,121896960,30474240]
shallow_throughput = [7203.61356805,7693.61785387,7732.62375173,7825.19402985,7826.41082258,7868.00812881,7874.16270338,
                       7903.83919598,7793.68968721,7850.82639214,118.88729107]

# %%
deep_memory = [121896960,121896960,121896960,121896960,121896960,121896960,121896960,121896960,121896960,121896960,50790400]
deep_throughput = [5994.0035727,5991.86285714,5994.71748452,5994.0035727,5994.71748452,5995.43156641,
                    5995.43156641,5995.43156641,3998.70088186,5998.289596,2497.20409621]

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1,len(shallow_memory)+1), shallow_memory, label='Shallow Model', color="tab:blue")
plt.plot(range(1,len(deep_memory) + 1), deep_memory, label='Deep Model', color="tab:red")
plt.xlabel('Batch Number')
plt.ylabel('Memory Usage (bytes)')
plt.title('Memory Usage by Batch')
plt.legend()
plt.savefig("/Users/Landon/Desktop/thesis/results/memory_usage.eps", format="eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1,len(shallow_throughput)+1), shallow_throughput, label='Shallow Model', color="tab:blue")
plt.plot(range(1,len(deep_throughput) + 1), deep_throughput, label='Deep Model', color="tab:red")
plt.xlabel('Batch Number')
plt.ylabel('Throughput (img/s)')
plt.title('Image Throughput by Batch')
plt.legend()
plt.savefig("/Users/Landon/Desktop/thesis/results/throughput.eps", format="eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
Training_set_size = 901
Validation_set_size = 225
Test_set_size = 125
def showDataLayout():
    plt.bar(["Train","Validation","Test"],
    [Training_set_size, Validation_set_size, Test_set_size], align='center',color=[ 'green','red', 'blue'])
    plt.legend()

    plt.ylabel('Number of Images')
    plt.title('Data Distribution')
    plt.savefig('data_distribution.eps', format="eps")
    plt.show()
    
showDataLayout()
# Out:
# C:\Users\Landon\AppData\Local\Temp\ipykernel_4624\2047676539.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
